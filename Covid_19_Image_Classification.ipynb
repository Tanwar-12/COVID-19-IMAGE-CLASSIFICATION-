# %% [markdown]
# # Project:Covid 19 Image Classification

# %% [markdown]
# ## Importing the necessary libraries

# %%
# Importing necessary library
import tensorflow as tf
import numpy as np
import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from keras.models import Model
from tensorflow.keras.models import Sequential
from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils
from glob import glob
import warnings
warnings.filterwarnings("ignore")

# %%
# Mounting the google drive 
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Loading training and testing folder path
train_dir = "/content/drive/MyDrive/Covid 19 Image classification/Covid 19 image dataset/Covid19-dataset/train"
test_dir = "/content/drive/MyDrive/Covid 19 Image classification/Covid 19 image dataset/Covid19-dataset/test"

# %%
# Generate traing and testing data

train_datagen = ImageDataGenerator(rescale=(1./255),
                                   rotation_range=40,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   zoom_range=0.2,
                                   shear_range=0.2,
                                   horizontal_flip = True,
                                   )

test_datagen = ImageDataGenerator(rescale=(1./255),
                                   rotation_range=40,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   zoom_range=0.2,
                                   shear_range=0.2,
                                   horizontal_flip = True,
                                   )


train_set = train_datagen.flow_from_directory(train_dir,target_size=(224,224),
                                              batch_size=32,class_mode='categorical')

test_set = test_datagen.flow_from_directory(test_dir, target_size=(224,224),
                                            batch_size=32, class_mode='categorical')
# Out:
# Found 251 images belonging to 3 classes.
# Found 66 images belonging to 3 classes.

# %% [markdown]
# ## Plotting training images

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimage
# %matplotlib inline

# %%
# Define function to plot training images
def plots(img, figsize=(20,10),rows=4, interp=False, title=None):
  fig = plt.figure(figsize=figsize)
  cols = len(img) // rows if len(img)%2 == 0 else len(img)//rows+1
  for i in range(len(img)):
    sp = fig.add_subplot(rows, cols, i+1)
    sp.axis('off')
    sp.set_title(class_names[title[i].tolist().index(1)], fontsize=16)
    plt.imshow(img[i])


# Making list of classes
class_names = ["Covid", "Normal", "Viral Pneumonia"]

# %%
img, labels = next(train_set)
plots(img, title=labels)

# %% [markdown]
# ### VGG 16 Model

# %%
image_size = [224,224]
vgg = VGG16(input_shape= image_size + [3], weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
# Dont train existing weights
for layer in vgg.layers:
  layer.trainable = False

# %%
# Getting the length of folders
folders = glob("/content/drive/MyDrive/Covid 19 Image classification/Covid 19 image dataset/Covid19-dataset/train/*")
print(len(folders))
# Out:
# 3

# %%
# VGG16 Architecture
x = Flatten()(vgg.output)
prediction = Dense(len(folders), activation='softmax')(x)
model16 = Model(inputs=vgg.input, outputs=prediction)

# %%
# Model Summary
model16.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_1 (Dense)             (None, 3)                 75267
#
# =================================================================
# Total params: 14,789,955
# Trainable params: 75,267
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# Plotting graphical representation of model
import keras
import pydotplus
from keras.utils.vis_utils import model_to_dot
keras.utils.vis_utils.plot_model(model16)

# %%
# Compile model
from tensorflow.keras.optimizers import Adam
model16.compile(loss='categorical_crossentropy', optimizer=Adam(0.01), metrics=['accuracy'])

# %%
# Fit(Train) the model
from keras.callbacks import ModelCheckpoint

check = ModelCheckpoint(filepath= 'vgg16model.h5', verbose=1, save_best_only=2)

hist = model16.fit(train_set, epochs=50, 
                   steps_per_epoch=5, 
                   validation_data=test_set, 
                   verbose=2, callbacks=check )
# Out:
# Epoch 1/50
#
# Epoch 1: val_loss improved from inf to 1.27642, saving model to vgg16model.h5
# 5/5 - 48s - loss: 12.4028 - accuracy: 0.2839 - val_loss: 1.2764 - val_accuracy: 0.6970 - 48s/epoch - 10s/step
# Epoch 2/50
#
# Epoch 2: val_loss did not improve from 1.27642
# 5/5 - 16s - loss: 7.1781 - accuracy: 0.6438 - val_loss: 4.0171 - val_accuracy: 0.6818 - 16s/epoch - 3s/step
# Epoch 3/50
#
# Epoch 3: val_loss did not improve from 1.27642
# 5/5 - 14s - loss: 2.4858 - accuracy: 0.7250 - val_loss: 3.9591 - val_accuracy: 0.6364 - 14s/epoch - 3s/step
# Epoch 4/50
#
# Epoch 4: val_loss did not improve from 1.27642
# 5/5 - 13s - loss: 1.9814 - accuracy: 0.7484 - val_loss: 1.2792 - val_accuracy: 0.7879 - 13s/epoch - 3s/step
# Epoch 5/50
#
# Epoch 5: val_loss did not improve from 1.27642
# 5/5 - 13s - loss: 1.5576 - accuracy: 0.8313 - val_loss: 1.7467 - val_accuracy: 0.7424 - 13s/epoch - 3s/step
# Epoch 6/50
#
# Epoch 6: val_loss improved from 1.27642 to 0.58926, saving model to vgg16model.h5
# 5/5 - 12s - loss: 1.5520 - accuracy: 0.8375 - val_loss: 0.5893 - val_accuracy: 0.8333 - 12s/epoch - 2s/step
# Epoch 7/50
#
# Epoch 7: val_loss did not improve from 0.58926
# 5/5 - 14s - loss: 0.9157 - accuracy: 0.8839 - val_loss: 2.6461 - val_accuracy: 0.7121 - 14s/epoch - 3s/step
# Epoch 8/50
#
# Epoch 8: val_loss did not improve from 0.58926
# 5/5 - 12s - loss: 0.6565 - accuracy: 0.8875 - val_loss: 0.7080 - val_accuracy: 0.8788 - 12s/epoch - 2s/step
# Epoch 9/50
#
# Epoch 9: val_loss did not improve from 0.58926
# 5/5 - 12s - loss: 1.7555 - accuracy: 0.8258 - val_loss: 5.9555 - val_accuracy: 0.6515 - 12s/epoch - 2s/step
# Epoch 10/50
#
# Epoch 10: val_loss did not improve from 0.58926
# 5/5 - 12s - loss: 2.5760 - accuracy: 0.7484 - val_loss: 4.3249 - val_accuracy: 0.6818 - 12s/epoch - 2s/step
# Epoch 11/50
#
# Epoch 11: val_loss did not improve from 0.58926
# 5/5 - 12s - loss: 2.2860 - accuracy: 0.7677 - val_loss: 4.6640 - val_accuracy: 0.6818 - 12s/epoch - 2s/step
# Epoch 12/50
#
# Epoch 12: val_loss did not improve from 0.58926
# 5/5 - 13s - loss: 1.4123 - accuracy: 0.8323 - val_loss: 1.2515 - val_accuracy: 0.8485 - 13s/epoch - 3s/step
# Epoch 13/50
#
# Epoch 13: val_loss did not improve from 0.58926
# 5/5 - 12s - loss: 1.1788 - accuracy: 0.8625 - val_loss: 1.7775 - val_accuracy: 0.6818 - 12s/epoch - 2s/step
# Epoch 14/50
#
# Epoch 14: val_loss did not improve from 0.58926
# 5/5 - 12s - loss: 0.8927 - accuracy: 0.9032 - val_loss: 0.8194 - val_accuracy: 0.8030 - 12s/epoch - 2s/step
# Epoch 15/50
#
# Epoch 15: val_loss did not improve from 0.58926
# 5/5 - 13s - loss: 0.8134 - accuracy: 0.8938 - val_loss: 0.9945 - val_accuracy: 0.8636 - 13s/epoch - 3s/step
# Epoch 16/50
#
# Epoch 16: val_loss did not improve from 0.58926
# 5/5 - 13s - loss: 0.5761 - accuracy: 0.9032 - val_loss: 3.2059 - val_accuracy: 0.7727 - 13s/epoch - 3s/step
# Epoch 17/50
#
# Epoch 17: val_loss did not improve from 0.58926
# 5/5 - 12s - loss: 0.8992 - accuracy: 0.8968 - val_loss: 1.0556 - val_accuracy: 0.8333 - 12s/epoch - 2s/step
# Epoch 18/50
#
# Epoch 18: val_loss did not improve from 0.58926
# 5/5 - 12s - loss: 0.8867 - accuracy: 0.9062 - val_loss: 0.8425 - val_accuracy: 0.8182 - 12s/epoch - 2s/step
# Epoch 19/50
#
# Epoch 19: val_loss improved from 0.58926 to 0.40529, saving model to vgg16model.h5
# 5/5 - 13s - loss: 0.5652 - accuracy: 0.9000 - val_loss: 0.4053 - val_accuracy: 0.9091 - 13s/epoch - 3s/step
# Epoch 20/50
#
# Epoch 20: val_loss did not improve from 0.40529
# 5/5 - 13s - loss: 0.5020 - accuracy: 0.9312 - val_loss: 0.5276 - val_accuracy: 0.9242 - 13s/epoch - 3s/step
# Epoch 21/50
#
# Epoch 21: val_loss did not improve from 0.40529
# 5/5 - 13s - loss: 0.2297 - accuracy: 0.9548 - val_loss: 0.9913 - val_accuracy: 0.8030 - 13s/epoch - 3s/step
# Epoch 22/50
#
# Epoch 22: val_loss did not improve from 0.40529
# 5/5 - 13s - loss: 0.2928 - accuracy: 0.9375 - val_loss: 1.5579 - val_accuracy: 0.8182 - 13s/epoch - 3s/step
# Epoch 23/50
#
# Epoch 23: val_loss did not improve from 0.40529
# 5/5 - 13s - loss: 0.6150 - accuracy: 0.9000 - val_loss: 0.6454 - val_accuracy: 0.8939 - 13s/epoch - 3s/step
# Epoch 24/50
#
# Epoch 24: val_loss did not improve from 0.40529
# 5/5 - 13s - loss: 0.6529 - accuracy: 0.8903 - val_loss: 1.8170 - val_accuracy: 0.7576 - 13s/epoch - 3s/step
# Epoch 25/50
#
# Epoch 25: val_loss improved from 0.40529 to 0.31647, saving model to vgg16model.h5
# 5/5 - 13s - loss: 0.9216 - accuracy: 0.8903 - val_loss: 0.3165 - val_accuracy: 0.9091 - 13s/epoch - 3s/step
# Epoch 26/50
#
# Epoch 26: val_loss did not improve from 0.31647
# 5/5 - 13s - loss: 0.7549 - accuracy: 0.8750 - val_loss: 1.2002 - val_accuracy: 0.8182 - 13s/epoch - 3s/step
# Epoch 27/50
#
# Epoch 27: val_loss did not improve from 0.31647
# 5/5 - 12s - loss: 0.8994 - accuracy: 0.8452 - val_loss: 1.2501 - val_accuracy: 0.7879 - 12s/epoch - 2s/step
# Epoch 28/50
#
# Epoch 28: val_loss did not improve from 0.31647
# 5/5 - 12s - loss: 1.0152 - accuracy: 0.9097 - val_loss: 0.4700 - val_accuracy: 0.9091 - 12s/epoch - 2s/step
# Epoch 29/50
#
# Epoch 29: val_loss did not improve from 0.31647
# 5/5 - 12s - loss: 0.1459 - accuracy: 0.9548 - val_loss: 1.8393 - val_accuracy: 0.8333 - 12s/epoch - 2s/step
# Epoch 30/50
#
# Epoch 30: val_loss did not improve from 0.31647
# 5/5 - 12s - loss: 0.3117 - accuracy: 0.9355 - val_loss: 0.6371 - val_accuracy: 0.9091 - 12s/epoch - 2s/step
# Epoch 31/50
#
# Epoch 31: val_loss did not improve from 0.31647
# 5/5 - 12s - loss: 0.6076 - accuracy: 0.9125 - val_loss: 0.4900 - val_accuracy: 0.8636 - 12s/epoch - 2s/step
# Epoch 32/50
#
# Epoch 32: val_loss improved from 0.31647 to 0.10430, saving model to vgg16model.h5
# 5/5 - 13s - loss: 0.2499 - accuracy: 0.9563 - val_loss: 0.1043 - val_accuracy: 0.9394 - 13s/epoch - 3s/step
# Epoch 33/50
#
# Epoch 33: val_loss did not improve from 0.10430
# 5/5 - 12s - loss: 0.3895 - accuracy: 0.9548 - val_loss: 0.9752 - val_accuracy: 0.8333 - 12s/epoch - 2s/step
# Epoch 34/50
#
# Epoch 34: val_loss did not improve from 0.10430
# 5/5 - 12s - loss: 0.4273 - accuracy: 0.9290 - val_loss: 1.0596 - val_accuracy: 0.8636 - 12s/epoch - 2s/step
# Epoch 35/50
#
# Epoch 35: val_loss did not improve from 0.10430
# 5/5 - 13s - loss: 0.4138 - accuracy: 0.9375 - val_loss: 0.3041 - val_accuracy: 0.9242 - 13s/epoch - 3s/step
# Epoch 36/50
#
# Epoch 36: val_loss did not improve from 0.10430
# 5/5 - 13s - loss: 0.4041 - accuracy: 0.9419 - val_loss: 0.7221 - val_accuracy: 0.9091 - 13s/epoch - 3s/step
# Epoch 37/50
#
# Epoch 37: val_loss did not improve from 0.10430
# 5/5 - 13s - loss: 0.3417 - accuracy: 0.9484 - val_loss: 1.0966 - val_accuracy: 0.7727 - 13s/epoch - 3s/step
# Epoch 38/50
#
# Epoch 38: val_loss did not improve from 0.10430
# 5/5 - 13s - loss: 0.2855 - accuracy: 0.9500 - val_loss: 0.8628 - val_accuracy: 0.8636 - 13s/epoch - 3s/step
# Epoch 39/50
#
# Epoch 39: val_loss did not improve from 0.10430
# 5/5 - 14s - loss: 0.3204 - accuracy: 0.9625 - val_loss: 0.6327 - val_accuracy: 0.8636 - 14s/epoch - 3s/step
# Epoch 40/50
#
# Epoch 40: val_loss did not improve from 0.10430
# 5/5 - 12s - loss: 0.3446 - accuracy: 0.9419 - val_loss: 0.5933 - val_accuracy: 0.8636 - 12s/epoch - 2s/step
# Epoch 41/50
#
# Epoch 41: val_loss did not improve from 0.10430
# 5/5 - 13s - loss: 0.1464 - accuracy: 0.9625 - val_loss: 0.2603 - val_accuracy: 0.9242 - 13s/epoch - 3s/step
# Epoch 42/50
#
# Epoch 42: val_loss did not improve from 0.10430
# 5/5 - 11s - loss: 0.3864 - accuracy: 0.9226 - val_loss: 0.6018 - val_accuracy: 0.8939 - 11s/epoch - 2s/step
# Epoch 43/50
#
# Epoch 43: val_loss did not improve from 0.10430
# 5/5 - 12s - loss: 0.3070 - accuracy: 0.9419 - val_loss: 0.9283 - val_accuracy: 0.8939 - 12s/epoch - 2s/step
# Epoch 44/50
#
# Epoch 44: val_loss did not improve from 0.10430
# 5/5 - 12s - loss: 0.2025 - accuracy: 0.9625 - val_loss: 0.7993 - val_accuracy: 0.8788 - 12s/epoch - 2s/step
# Epoch 45/50
#
# Epoch 45: val_loss did not improve from 0.10430
# 5/5 - 12s - loss: 0.0767 - accuracy: 0.9806 - val_loss: 0.8530 - val_accuracy: 0.8636 - 12s/epoch - 2s/step
# Epoch 46/50
#
# Epoch 46: val_loss did not improve from 0.10430
# 5/5 - 12s - loss: 0.3150 - accuracy: 0.9548 - val_loss: 1.4861 - val_accuracy: 0.7727 - 12s/epoch - 2s/step
# Epoch 47/50
#
# Epoch 47: val_loss did not improve from 0.10430
# 5/5 - 12s - loss: 0.3528 - accuracy: 0.9677 - val_loss: 0.4057 - val_accuracy: 0.9242 - 12s/epoch - 2s/step
# Epoch 48/50
#
# Epoch 48: val_loss did not improve from 0.10430
# 5/5 - 13s - loss: 0.1850 - accuracy: 0.9613 - val_loss: 2.7258 - val_accuracy: 0.7576 - 13s/epoch - 3s/step
# Epoch 49/50
#
# Epoch 49: val_loss did not improve from 0.10430
# 5/5 - 11s - loss: 0.4683 - accuracy: 0.9226 - val_loss: 0.6980 - val_accuracy: 0.9091 - 11s/epoch - 2s/step
# Epoch 50/50
#
# Epoch 50: val_loss did not improve from 0.10430
# 5/5 - 12s - loss: 0.4666 - accuracy: 0.9355 - val_loss: 0.6363 - val_accuracy: 0.8788 - 12s/epoch - 2s/step

# %%
train_result = model16.evaluate(train_set)
print("Train Accuracy & Loss:",train_result)

test_result = model16.evaluate(test_set)
print("Testing Accuracy & Loss",test_result)
# Out:
# 8/8 [==============================] - 14s 2s/step - loss: 0.1522 - accuracy: 0.9562
# Train Accuracy & Loss: [0.1521943211555481, 0.9561753273010254]
# 3/3 [==============================] - 3s 585ms/step - loss: 0.1474 - accuracy: 0.9394
# Testing Accuracy & Loss [0.14740914106369019, 0.939393937587738]

# %%
# Creating dataframe
import pandas as pd
data = pd.DataFrame(zip(train_result, test_result),columns=['Train','Test'],index=['Loss','Accuracy'])
data
# Out:
#              Train      Test
# Loss      0.152194  0.147409
# Accuracy  0.956175  0.939394

# %%
# Plotting training and testing Accuracy as well as loss & val loss

def plot_curve(hist):
  acc      = hist.history['accuracy']
  val_acc  = hist.history['val_accuracy']
  loss     = hist.history['loss']
  val_loss = hist.history['val_loss']
  epochs   = range(len(acc))

  plt.plot(epochs, acc, label='accuracy')
  plt.plot(epochs, val_acc, label='val_accuracy')
  plt.legend()
  plt.figure()

  plt.plot(epochs, loss, label='loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.legend()
  plt.figure()

plot_curve(hist)

# %% [markdown]
# #VGG19 Model

# %%
vgg1 = VGG19(input_shape= image_size + [3], weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step

# %%
# Dont train existing weights
for layer in vgg1.layers:
  layer.trainable = False

# %%
# VGG16 Architecture
x = Flatten()(vgg1.output)
prediction = Dense(len(folders), activation='softmax')(x)
model19 = Model(inputs=vgg1.input, outputs=prediction)

# %%
# Plotting graphical representation of model
import keras
import pydotplus
from keras.utils.vis_utils import model_to_dot
keras.utils.vis_utils.plot_model(model19)

# %%
# Model Sumaary
model19.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  dense_2 (Dense)             (None, 3)                 75267
#
# =================================================================
# Total params: 20,099,651
# Trainable params: 75,267
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
# Compile model
from tensorflow.keras.optimizers import Adam
model19.compile(loss='categorical_crossentropy', optimizer=Adam(0.01), metrics=['accuracy'])

# %%
# Fit(Train) the model
from keras.callbacks import ModelCheckpoint

check = ModelCheckpoint(filepath= 'vgg19model.h5', verbose=1, save_best_only=2)

History = model19.fit_generator(train_set, epochs=40, 
                                steps_per_epoch=5, 
                                validation_data=test_set, 
                                verbose=2, callbacks=check )
# Out:
# Epoch 1/40
#
# Epoch 1: val_loss improved from inf to 11.53132, saving model to vgg19model.h5
# 5/5 - 15s - loss: 23.1464 - accuracy: 0.3375 - val_loss: 11.5313 - val_accuracy: 0.4091 - 15s/epoch - 3s/step
# Epoch 2/40
#
# Epoch 2: val_loss improved from 11.53132 to 10.72954, saving model to vgg19model.h5
# 5/5 - 13s - loss: 15.9862 - accuracy: 0.4710 - val_loss: 10.7295 - val_accuracy: 0.5455 - 13s/epoch - 3s/step
# Epoch 3/40
#
# Epoch 3: val_loss improved from 10.72954 to 8.63822, saving model to vgg19model.h5
# 5/5 - 13s - loss: 11.0822 - accuracy: 0.5161 - val_loss: 8.6382 - val_accuracy: 0.4545 - 13s/epoch - 3s/step
# Epoch 4/40
#
# Epoch 4: val_loss improved from 8.63822 to 1.91324, saving model to vgg19model.h5
# 5/5 - 13s - loss: 7.3418 - accuracy: 0.5806 - val_loss: 1.9132 - val_accuracy: 0.7424 - 13s/epoch - 3s/step
# Epoch 5/40
#
# Epoch 5: val_loss did not improve from 1.91324
# 5/5 - 12s - loss: 3.5257 - accuracy: 0.7000 - val_loss: 5.4323 - val_accuracy: 0.6515 - 12s/epoch - 2s/step
# Epoch 6/40
#
# Epoch 6: val_loss improved from 1.91324 to 1.21723, saving model to vgg19model.h5
# 5/5 - 13s - loss: 3.7431 - accuracy: 0.7226 - val_loss: 1.2172 - val_accuracy: 0.7424 - 13s/epoch - 3s/step
# Epoch 7/40
#
# Epoch 7: val_loss did not improve from 1.21723
# 5/5 - 12s - loss: 3.5044 - accuracy: 0.7355 - val_loss: 1.4843 - val_accuracy: 0.7727 - 12s/epoch - 2s/step
# Epoch 8/40
#
# Epoch 8: val_loss improved from 1.21723 to 1.04119, saving model to vgg19model.h5
# 5/5 - 12s - loss: 2.0347 - accuracy: 0.8129 - val_loss: 1.0412 - val_accuracy: 0.8636 - 12s/epoch - 2s/step
# Epoch 9/40
#
# Epoch 9: val_loss did not improve from 1.04119
# 5/5 - 12s - loss: 1.5466 - accuracy: 0.8452 - val_loss: 3.0710 - val_accuracy: 0.6667 - 12s/epoch - 2s/step
# Epoch 10/40
#
# Epoch 10: val_loss improved from 1.04119 to 0.61483, saving model to vgg19model.h5
# 5/5 - 13s - loss: 1.1618 - accuracy: 0.8710 - val_loss: 0.6148 - val_accuracy: 0.9242 - 13s/epoch - 3s/step
# Epoch 11/40
#
# Epoch 11: val_loss improved from 0.61483 to 0.49029, saving model to vgg19model.h5
# 5/5 - 13s - loss: 1.5159 - accuracy: 0.8516 - val_loss: 0.4903 - val_accuracy: 0.8788 - 13s/epoch - 3s/step
# Epoch 12/40
#
# Epoch 12: val_loss improved from 0.49029 to 0.47748, saving model to vgg19model.h5
# 5/5 - 12s - loss: 0.7682 - accuracy: 0.8774 - val_loss: 0.4775 - val_accuracy: 0.8636 - 12s/epoch - 2s/step
# Epoch 13/40
#
# Epoch 13: val_loss did not improve from 0.47748
# 5/5 - 12s - loss: 0.8899 - accuracy: 0.8774 - val_loss: 0.5578 - val_accuracy: 0.8939 - 12s/epoch - 2s/step
# Epoch 14/40
#
# Epoch 14: val_loss improved from 0.47748 to 0.21854, saving model to vgg19model.h5
# 5/5 - 12s - loss: 0.4231 - accuracy: 0.9032 - val_loss: 0.2185 - val_accuracy: 0.9242 - 12s/epoch - 2s/step
# Epoch 15/40
#
# Epoch 15: val_loss did not improve from 0.21854
# 5/5 - 13s - loss: 0.6513 - accuracy: 0.9032 - val_loss: 1.1240 - val_accuracy: 0.8333 - 13s/epoch - 3s/step
# Epoch 16/40
#
# Epoch 16: val_loss did not improve from 0.21854
# 5/5 - 12s - loss: 0.4557 - accuracy: 0.9355 - val_loss: 0.5241 - val_accuracy: 0.8939 - 12s/epoch - 2s/step
# Epoch 17/40
#
# Epoch 17: val_loss did not improve from 0.21854
# 5/5 - 12s - loss: 0.9636 - accuracy: 0.8645 - val_loss: 1.1925 - val_accuracy: 0.8182 - 12s/epoch - 2s/step
# Epoch 18/40
#
# Epoch 18: val_loss did not improve from 0.21854
# 5/5 - 12s - loss: 0.5579 - accuracy: 0.9125 - val_loss: 0.6132 - val_accuracy: 0.8939 - 12s/epoch - 2s/step
# Epoch 19/40
#
# Epoch 19: val_loss did not improve from 0.21854
# 5/5 - 12s - loss: 0.8860 - accuracy: 0.8625 - val_loss: 0.7500 - val_accuracy: 0.8788 - 12s/epoch - 2s/step
# Epoch 20/40
#
# Epoch 20: val_loss did not improve from 0.21854
# 5/5 - 13s - loss: 0.5932 - accuracy: 0.8813 - val_loss: 0.6898 - val_accuracy: 0.8788 - 13s/epoch - 3s/step
# Epoch 21/40
#
# Epoch 21: val_loss did not improve from 0.21854
# 5/5 - 12s - loss: 0.4949 - accuracy: 0.9355 - val_loss: 0.7564 - val_accuracy: 0.8788 - 12s/epoch - 2s/step
# Epoch 22/40
#
# Epoch 22: val_loss did not improve from 0.21854
# 5/5 - 12s - loss: 0.4894 - accuracy: 0.9161 - val_loss: 0.3111 - val_accuracy: 0.8939 - 12s/epoch - 2s/step
# Epoch 23/40
#
# Epoch 23: val_loss did not improve from 0.21854
# 5/5 - 12s - loss: 0.2281 - accuracy: 0.9419 - val_loss: 2.1607 - val_accuracy: 0.7424 - 12s/epoch - 2s/step
# Epoch 24/40
#
# Epoch 24: val_loss did not improve from 0.21854
# 5/5 - 13s - loss: 0.4218 - accuracy: 0.9097 - val_loss: 0.7233 - val_accuracy: 0.8030 - 13s/epoch - 3s/step
# Epoch 25/40
#
# Epoch 25: val_loss did not improve from 0.21854
# 5/5 - 12s - loss: 0.8109 - accuracy: 0.8875 - val_loss: 1.8962 - val_accuracy: 0.7273 - 12s/epoch - 2s/step
# Epoch 26/40
#
# Epoch 26: val_loss did not improve from 0.21854
# 5/5 - 12s - loss: 0.4749 - accuracy: 0.9125 - val_loss: 0.4238 - val_accuracy: 0.9242 - 12s/epoch - 2s/step
# Epoch 27/40
#
# Epoch 27: val_loss did not improve from 0.21854
# 5/5 - 12s - loss: 0.6983 - accuracy: 0.8903 - val_loss: 0.8988 - val_accuracy: 0.8485 - 12s/epoch - 2s/step
# Epoch 28/40
#
# Epoch 28: val_loss did not improve from 0.21854
# 5/5 - 12s - loss: 0.2144 - accuracy: 0.9548 - val_loss: 0.5254 - val_accuracy: 0.8333 - 12s/epoch - 2s/step
# Epoch 29/40
#
# Epoch 29: val_loss did not improve from 0.21854
# 5/5 - 12s - loss: 0.2506 - accuracy: 0.9438 - val_loss: 0.8746 - val_accuracy: 0.8939 - 12s/epoch - 2s/step
# Epoch 30/40
#
# Epoch 30: val_loss did not improve from 0.21854
# 5/5 - 12s - loss: 0.1347 - accuracy: 0.9563 - val_loss: 0.2659 - val_accuracy: 0.8939 - 12s/epoch - 2s/step
# Epoch 31/40
#
# Epoch 31: val_loss did not improve from 0.21854
# 5/5 - 12s - loss: 0.1204 - accuracy: 0.9750 - val_loss: 0.3571 - val_accuracy: 0.9242 - 12s/epoch - 2s/step
# Epoch 32/40
#
# Epoch 32: val_loss did not improve from 0.21854
# 5/5 - 13s - loss: 0.2548 - accuracy: 0.9742 - val_loss: 0.7296 - val_accuracy: 0.8636 - 13s/epoch - 3s/step
# Epoch 33/40
#
# Epoch 33: val_loss did not improve from 0.21854
# 5/5 - 13s - loss: 0.3859 - accuracy: 0.9355 - val_loss: 0.9083 - val_accuracy: 0.7879 - 13s/epoch - 3s/step
# Epoch 34/40
#
# Epoch 34: val_loss improved from 0.21854 to 0.19275, saving model to vgg19model.h5
# 5/5 - 11s - loss: 0.2798 - accuracy: 0.9355 - val_loss: 0.1928 - val_accuracy: 0.9394 - 11s/epoch - 2s/step
# Epoch 35/40
#
# Epoch 35: val_loss did not improve from 0.19275
# 5/5 - 12s - loss: 0.7780 - accuracy: 0.8839 - val_loss: 0.2378 - val_accuracy: 0.9545 - 12s/epoch - 2s/step
# Epoch 36/40
#
# Epoch 36: val_loss did not improve from 0.19275
# 5/5 - 12s - loss: 0.4446 - accuracy: 0.9290 - val_loss: 1.0765 - val_accuracy: 0.8636 - 12s/epoch - 2s/step
# Epoch 37/40
#
# Epoch 37: val_loss did not improve from 0.19275
# 5/5 - 12s - loss: 0.5876 - accuracy: 0.9032 - val_loss: 0.4862 - val_accuracy: 0.8939 - 12s/epoch - 2s/step
# Epoch 38/40
#
# Epoch 38: val_loss did not improve from 0.19275
# 5/5 - 12s - loss: 0.5211 - accuracy: 0.8968 - val_loss: 0.3091 - val_accuracy: 0.9545 - 12s/epoch - 2s/step
# Epoch 39/40
#
# Epoch 39: val_loss did not improve from 0.19275
# 5/5 - 13s - loss: 0.6379 - accuracy: 0.8875 - val_loss: 0.6362 - val_accuracy: 0.8485 - 13s/epoch - 3s/step
# Epoch 40/40
#
# Epoch 40: val_loss did not improve from 0.19275
# 5/5 - 12s - loss: 1.1254 - accuracy: 0.8839 - val_loss: 0.2466 - val_accuracy: 0.9394 - 12s/epoch - 2s/step

# %%
train_result = model19.evaluate(train_set)
print("Train Accuracy & Loss:",train_result)

test_result = model19.evaluate(test_set)
print("Testing Accuracy & Loss",test_result)
# Out:
# 8/8 [==============================] - 14s 2s/step - loss: 0.1611 - accuracy: 0.9641
# Train Accuracy & Loss: [0.16114503145217896, 0.9641434550285339]
# 3/3 [==============================] - 2s 607ms/step - loss: 0.3918 - accuracy: 0.9242
# Testing Accuracy & Loss [0.391777366399765, 0.9242424368858337]

# %%
# Creating dataframe
import pandas as pd
df = pd.DataFrame(zip(train_result, test_result),columns=['Train','Test'],index=['Loss','Accuracy'])
df
# Out:
#              Train      Test
# Loss      0.161145  0.391777
# Accuracy  0.964143  0.924242

# %%
# Plotting training and testing Accuracy as well as loss & val loss

def plot_curve(hist):
  acc      = History.history['accuracy']
  val_acc  = History.history['val_accuracy']
  loss     = History.history['loss']
  val_loss = History.history['val_loss']
  epochs   = range(len(acc))

  plt.plot(epochs, acc, label='accuracy')
  plt.plot(epochs, val_acc, label='val_accuracy')
  plt.legend()
  plt.figure()

  plt.plot(epochs, loss, label='loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.legend()
  plt.figure()

plot_curve(hist)
